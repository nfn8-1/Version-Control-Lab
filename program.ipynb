# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hello {name}, you are {age} years old")
# Out:
# Enter your name:  noah
# Enter your age:  19
# Hello noah, you are 19 years old
